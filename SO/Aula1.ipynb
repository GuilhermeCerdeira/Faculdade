# %% [markdown]
# # C vs PYTHON

# %% [markdown]
# Python é interpretado, então ele é primeiro passado para um tradutor que converte em bytecode e depois passa pelo interpretador

# %% [markdown]
# ![image.png](attachment:a1389545-382d-4ac5-80e9-844d9bb9e664.png)
