# %% [markdown]
# **1) Introdução**
#
# 1) Por que um compilador C não gera um arquivo executável diretamente do código-fonte?
#
# 2) Após o processo de ligação, qual a posição (endereço) da sub-rotina main()?
#
# 3) Dentro do computador, quem se importa (e por quê) com a resposta da pergunta 2?
#
# 4) Como é possível executar dois programas, simultaneamente, em um computador com um microprocessador de núcleo único?
#
# 5) Calcule uma estimativa do tempo necessário para copiar 1 MiByte de dados de um arquivo para outro arquivo no mesmo HD, verifique informações na Internet e calcule um valor aproximado.
#
# 6) Repita 5) para SSD e memória RAM.
#
# ---
#
# **2) Relocação**
#
# 1) Existem dois computadores, A e B. A possui os registradores BASE/LIMITE, B não possui este recurso. Faça uma comparação entre eles, considerando que você faz parte de uma equipe construindo um novo S.O.
#
# 2) Escreva código C/C++ para sondar os endereços limite de uma aplicação. Cuidado, o espaço provavelmente será bem grande (assim como os números que você terá que imprimir).
#
# 3) Vimos que trocando o valor do IP o SO é capaz de rodar vários programas lado a lado. O que acontece com as CPUs multi-core e que são equipadas para proteger a memória?
#
# 4) Como o O.S. sabe quais valores atribuir aos registradores BASE/LIMITE? Esboce o código para carregar e executar uma aplicação - imagine que você está criando um O.S.
#
# ---
#
# **4) Pilha e sub-rotinas**
#
# 1) Explique o que há de errado com o seguinte código:
#
# ```c
# int *muito_ruim() {
#     int i = 123;
#     retornar &i;
# }
# ```
#
# 2) Um computador com CPU mono-core executa vários aplicativos. Quais dados devem ser salvos para alternar entre os programas?
#
# 3) Micro Projeto: usando ponteiros, navegue na pilha e altere os valores das variáveis ​​locais de uma sub-rotina, imprima os endereços na tela.
#
# 4) Como podemos determinar o tamanho máximo da pilha sem ler nenhuma documentação? Escreva o código e execute um teste.
#
# 5) As aplicações são fechadas dentro dos registradores BASE/LIMITE, mas precisam chamar o SO para fazer coisas como imprimir na tela. Pense a respeito, faça diagramas, identifique um problema essa ideia.
#
# 6) Se um computador possui CPU quad-core, quantas pilhas existem? Após responder a esta questão, faça um desenho para representar seu raciocínio.
#
# 7) Sua resposta à pergunta anterior é válida se a CPU quad-core estiver executando seis aplicativos?
#
# 8) Examine o código a seguir, deduza e explique o que será mostrado na tela. Após responder, execute o código (no gcc, compile-o com a opção -O0 para desabilitar as otimizações).
#
# ```c
# vazio f () {
#     int x = 321;
#     printf("%d",x);
# }
#
# void g () {
#     int y;
#     printf("%d",y);
# }
#
# int principal ();
# f();
# g();
# retorna 0;
# }
# ```
#
# 9) Descreva o conteúdo da pilha para o código a seguir, logo antes da execução da instrução de retorno.
#
# ```c
# int main (int argv, char *argc[]) {
#     int n = 0;
#     retornar n;
# }
# ```
#
# ---
#
# **5) Estouro de buffer**
#
# 1) Hackers usam um teclado para executar um ataque de estouro de buffer e injetar um vírus em um computador. Mas... não dá certo. Por que?
#
# 2) Um computador é equipado com uma CPU simples, sem proteção de memória. Liste os dados que devem ser guardados quando há chaveamento de execução entre dois programas.
#
# 3) A maioria das barreiras contra um ataque de buffer overflow apenas diminui a probabilidade de um hacker atingir o objetivo. Explique por que isso acontece, para cada mecanismo de proteção explicado na aula.
#
# 4) Escreva um programa com uma função f() que faça qualquer coisa, como imprimir uma mensagem na tela. Em seguida, use um ponteiro de função *p para obter o endereço de f(). Faça uma chamada para p(). Teste isso, escreva na memória em *p.
#
# 5) Em que momento uma proteção por canário deve ser capaz de detectar acessos inválidos? As opções são: (i) durante uma chamada a uma função, (ii) durante a execução da função, (iii) ao retornar ao chamador. Escolha opção e explique o motivo. Depois de explicar sua resposta, escreva sua própria implementação de canário.
#
# 6) As ilustrações da aula representam ataques que visam variáveis locais. É possível fazer o mesmo com variáveis globais? Desenhe. Explique.
#
# ---
#
# **6) E/S**
#
# 1) Polling e DMA são duas técnicas para lidar com E/S. Microprocessadores também dispõem de portas de E/S e E/S mapeadas em memória. Isso dá um total de 4 (quatro) combinações diferentes para fazer E/S. Comente e compare as quatro.
#
# 3) Qual é a diferença entre read() e fread()?
#
# 4) Descubra qual é o propósito de fdopen(). Em seguida, procure por uma função que faça o inverso.
#
# 5) As E/S síncronas e assíncronas dependem do dispositivo usado ou é simplesmente uma escolha do programador?
#
# 7) Explique diferenças entre E/S síncrona e assíncrona.
#
# 8) Explique o que é um pseudo-arquivo e como funciona; use como exemplo
# /proc/meminfo.
#
# 9) Explique os termos e siglas DMA, PIO, polling, portas.
#
# 10) Telacione o tamanho do cache de CPU com o uso ou não de DMA.
